# %%
import httpx
base_url='http://127.0.0.1'
username='admin'
password='1234567890'
client=httpx.Client(base_url=base_url, auth=(username,password))
# client=httpx.Client(
#                 base_url=self.base_url,
#                 auth=(username, token)
#             )

# %%
client

# %%
url='http://localhost:3000/login.xml'
import requests
